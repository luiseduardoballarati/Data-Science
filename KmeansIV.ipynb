# %% [markdown]
# # Kmeans IV
#
# O acesso à água potável é essencial para a saúde, um direito humano básico e um componente de uma política efetiva de proteção à saúde. Isto é importante como uma questão de saúde e desenvolvimento a nível nacional, regional e local. Em algumas regiões, foi demonstrado que os investimentos em abastecimento de água e saneamento podem gerar um benefício econômico líquido, uma vez que as reduções nos efeitos adversos à saúde e nos custos de saúde superam os custos de realização das intervenções.
#
# O presente trabalho visa determinar se a água, dadas as caracteísticas apresentadas é potável ou não.
#
# Suas colunas:
#
# 1. pH
#   - O pH é um parâmetro importante na avaliação do equilíbrio ácido-base da água. É também o indicador da condição ácida ou alcalina do estado da água. A OMS recomendou o limite máximo permitido de pH de 6,5 a 8,5. Os intervalos de investigação atuais foram de 6,52 a 6,83, que estão na faixa dos padrões da OMS.
# 2. Hardness (dureza)
#   - A dureza é causada principalmente por sais de cálcio e magnésio. Esses sais são dissolvidos a partir de depósitos geológicos através dos quais a água viaja. O período de tempo em que a água está em contato com o material produtor de dureza ajuda a determinar quanta dureza existe na água bruta. A dureza foi originalmente definida como a capacidade da água de precipitar sabão causada por cálcio e magnésio.
# 3. Solids (Sólidos): TDS (Total de sóliods dissolvidos)
#   - A água tem a capacidade de dissolver uma ampla gama de minerais ou sais inorgânicos e alguns orgânicos, como potássio, cálcio, sódio, bicarbonatos, cloretos, magnésio, sulfatos, etc. Esses minerais produziram sabor indesejado e cor diluída na aparência da água. Este é o parâmetro importante para o uso da água. A água com alto valor de TDS indica que a água é altamente mineralizada. O limite desejável para TDS é de 500 mg/le o limite máximo é de 1000 mg/l prescrito para beber.
# 4. Chloramines (Cloraminas)
#   - Cloro e cloramina são os principais desinfetantes usados ​​em sistemas públicos de água. As cloraminas são mais comumente formadas quando a amônia é adicionada ao cloro para tratar a água potável. Níveis de cloro de até 4 miligramas por litro (mg/L ou 4 partes por milhão (ppm)) são considerados seguros na água potável.
# 5. Sulfates (Sulfatos)
#   - Os sulfatos são substâncias naturais encontradas em minerais, solo e rochas. Eles estão presentes no ar ambiente, águas subterrâneas, plantas e alimentos. O principal uso comercial do sulfato é na indústria química. A concentração de sulfato na água do mar é de cerca de 2.700 miligramas por litro (mg/L). Varia de 3 a 30 mg/L na maioria dos suprimentos de água doce, embora concentrações muito mais altas (1000 mg/L) sejam encontradas em algumas localizações geográficas.
# 6. Condutivity (COndutividade)
#   - A água pura não é um bom condutor de corrente elétrica, mas um bom isolante. O aumento da concentração de íons aumenta a condutividade elétrica da água. Geralmente, a quantidade de sólidos dissolvidos na água determina a condutividade elétrica. A condutividade elétrica (EC) realmente mede o processo iônico de uma solução que lhe permite transmitir corrente. De acordo com os padrões da OMS, o valor EC não deve exceder 400 μS/cm.
# 7. Organic_Carbon (Carbono Orgânico)
#   - O Carbono Orgânico Total (COT) nas águas de nascente vem de matéria orgânica natural em decomposição (NOM), bem como de fontes sintéticas. TOC é uma medida da quantidade total de carbono em compostos orgânicos em água pura. De acordo com a US EPA < 2 mg/L como TOC em água tratada/potável, e < 4 mg/Lit em água de fonte que é usada para tratamento.
#
# 8. Trialometanos (Trihalometanos)
#    - THMs são produtos químicos que podem ser encontrados em água tratada com cloro. A concentração de THMs na água potável varia de acordo com o nível de matéria orgânica na água, a quantidade de cloro necessária para tratar a água e a temperatura da água que está sendo tratada. Níveis de THM de até 80 ppm são considerados seguros na água potável.
#    9. Turbidity (Turbidez)
#   - A turbidez da água depende da quantidade de matéria sólida presente no estado suspenso. É uma medida das propriedades de emissão de luz da água e o teste é usado para indicar a qualidade da descarga de resíduos em relação à matéria coloidal. O valor médio de turbidez obtido para o Wondo Genet Campus (0,98 NTU) é inferior ao valor recomendado pela OMS de 5,00 NTU.
#   10. Potability (Potabilidade)
#   - Indica se a água é segura para consumo humano onde 1 significa Potável e 0 significa Não potável.

# %% [markdown]
# Importação e tratamento dos dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/water_potability.csv')
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# Observação de valores faltantes:

# %%
print(f'Número de linhas e colunas do dataset: {df.shape}')
print('\n')
df.info()
# Out:
# Número de linhas e colunas do dataset: (3276, 10)
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# - pH: 491 valores faltantes
# - Hardness: 0 valores faltantes
# - Solids: 0 valores faltantes
# - Chloramines: 0 valores faltantes
# - Sulfate: 781 valores faltantes
# - Conductivity: 0 valores faltantes
# - Organic_carbon: 0 valores faltantes
# - Trihalomethanes: 162 valorea faltantes
# - Turbidity: 0 valores faltantes
# - Potability: 0 valores faltantes
#
# Tem muitos valores faltante. Vamos observar melhor:

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %% [markdown]
# Podemos observar que todas colunas tem máximos e mínimos em intervalos aceitáveis e que teremos que normalizar os dados para que o modelo não deixe as diferenças distâncias euclidianas afetar o agrupamento dos clusters. Caso contrário, a variável Solids, por exemplo, que tem ordem de grandeza na casa da dezena de milhar vai enviesar o agrupamento.

# %% [markdown]
# Para a variável, os 162 dados faltantes representam 4.95% dos dados totais. Como é pouco representativo vamos substituir os valores faltantes pela média:

# %%
df.Trihalomethanes.fillna(df.Trihalomethanes.mean(), inplace = True)

# %%
df.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes      0
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# Vamos fazer a mesma coisa para a variável sulfato, mas por outro motivo. Por mais que dos 3276 dados, quase 1/4 é faltante (23.85%), o desvio padrão é baixo, proporcionalemnte é de 12.31%. isso quer dizer que os dados estão bem perto da média e por conta disso preencheremos os dados faltantes com a média também:

# %%
df.Sulfate.fillna(df.Sulfate.mean(), inplace = True)

# %%
df.ph.describe()
# Out:
# count    2785.000000
# mean        7.080795
# std         1.594320
# min         0.000000
# 25%         6.093092
# 50%         7.036752
# 75%         8.062066
# max        14.000000
# Name: ph, dtype: float64

# %% [markdown]
# Para a variável pH, há 491 dados faltantes, 14.9% do total. Apesar do desvio padrão não ser baixo proporcionalmente, vamos substituir pela média também.

# %%
df.ph.fillna(df.ph.mean(), inplace = True)

# %% [markdown]
# Quando temos dados faltantes, o primeiro passo a se tomar é entender porquê esses dados estão faltando e se tem como acessá-los. Não sendo possível, temos duas opções: deleção ou imputação.
#
# Como nosso df é pequeno, deletar iria dificultar a vida do algoritmo. Dessa forma, por mais que provavelmente houvesse melhores formas, decidimos imputar os dados com a média.
#
# Além disso, pudemos observar que o mínimo valor do ph era 0. Se esse for um caso isolado, podemos tratar com uma normalidade do modelo e aquela linha tem de fato ph = 0. Se houver mais casos, vamos ter que nos aprofundar e ver de tomar uma atitude:

# %%
df.query('ph == 0').count()
# Out:
# ph                 1
# Hardness           1
# Solids             1
# Chloramines        1
# Sulfate            1
# Conductivity       1
# Organic_carbon     1
# Trihalomethanes    1
# Turbidity          1
# Potability         1
# dtype: int64

# %% [markdown]
# Só existe um valor com ph = 0, vamos assumi-lo como um valor normal e aceitável.
#
# Vamos agora para as análises exploratórias.

# %%
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.pie(df.Potability.value_counts(), labels=['Não Potável', 'Potável'], autopct='%.0f%%')
plt.legend()
plt.show()

# %% [markdown]
# De todos os dados, 1278 (39%) são de água potável e 1998 (61%) de não potável.

# %%
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

sns.histplot(data=df, x="ph", ax=axes[0])
axes[0].set_title('Distribuição da variável Solids')

sns.histplot(data=df, x="Sulfate", ax=axes[1])
axes[1].set_title('Distribuição da variável Sulfate')

sns.histplot(data=df, x="Trihalomethanes", ax=axes[2])
axes[2].set_title('Distribuição da variável Trihalomethanes')
# Out:
# Text(0.5, 1.0, 'Distribuição da variável Trihalomethanes')

# %% [markdown]
# Fica evidente que nosso tratamento dos dados, ao inserir a média em valores faltantes alterou o comportamento das variáveis.
#
# Para todas variáveis alteradas, valor de maior ocorrência virou a média e de longe, mas ainda assim podemos observar que:
#
# - o ph respeita uma distribuição normal e que a vasta maioria dos dados se encontra entre 4 < ph < 10.
# - o sulfato também tem uma distribuição normal com a maioria dos dados entre 250 < sulfato < 400.
# - a variável Trihalomethanes também segue essa distribuição e, como inserimos menos valores, a diferença ficou menos atenuante, mas ainda assim afeta. O intervalo em que os dados mais ocorrem é 40 < Trihalomethanes < 100.
#
# Vamos comparar caso não tivéssemos feito as alterações e adicionar o comparativo entre potável x não potável:

# %%
df_ = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/water_potability.csv')

fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

sns.histplot(data=df_, x="ph", ax=axes[0],hue="Potability", kde=True, element="step")
axes[0].set_title('Distribuição da variável Solids')

sns.histplot(data=df_, x="Sulfate", ax=axes[1], hue="Potability", kde=True,element="step")
axes[1].set_title('Distribuição da variável Sulfate')

sns.histplot(data=df_, x="Trihalomethanes", ax=axes[2], hue="Potability",kde=True,element="step")
axes[2].set_title('Distribuição da variável Trihalomethanes')
# Out:
# Text(0.5, 1.0, 'Distribuição da variável Trihalomethanes')

# %% [markdown]
# Ainda seguiram a mesma distribuição e os mesmos intervalos para ph e Trihalomethanes. Para a variável Sulfatem a inserção de dados deslocou o gráfico para a direita, tanto é que acima a variávem tem a maioria de seus valores entre 200 < Sulfate < 400. Vamos seguir com o dataset com a inserção dos dados.
#
# Comparando agora água potável x não potável podemos já tirar alguns insights:
# - As distribuições seguem muito parecidas para potável x não potável para as variáveis em questão. Ou seja, a média de ph, sulfato e Trihalomethanes segue segue parecida. O comportamento estatístico para essas variáveis é parecido para potável x não potável.
#
# Vamos ver o comportamento das outras variáveis.

# %%
print(f"Datset com a inserção de dados:\n {round(df[['ph', 'Sulfate', 'Trihalomethanes']].describe())}")
print(f"\nDatset sem a inserção de dados:\n {round(df_[['ph', 'Sulfate', 'Trihalomethanes']].describe())}")
# Out:
# Datset com a inserção de dados:
#             ph  Sulfate  Trihalomethanes
# count  3276.0   3276.0           3276.0
# mean      7.0    334.0             66.0
# std       1.0     36.0             16.0
# min       0.0    129.0              1.0
# 25%       6.0    317.0             57.0
# 50%       7.0    334.0             66.0
# 75%       8.0    350.0             77.0
# max      14.0    481.0            124.0
#
# Datset sem a inserção de dados:
#             ph  Sulfate  Trihalomethanes
# count  2785.0   2495.0           3114.0
# mean      7.0    334.0             66.0
# std       2.0     41.0             16.0
# min       0.0    129.0              1.0
# 25%       6.0    308.0             56.0
# 50%       7.0    333.0             67.0
# 75%       8.0    360.0             77.0
# max      14.0    481.0            124.0

# %% [markdown]
# Mais detalhadamente, podemos observar que a média, o mínimo, o máximo não mudaram.
#
# Para o ph, nada mudou a não ser a contagem (o count() não conta valores vazios), nem os quartis. Perfeito.
#
# Para as variáveis Sulfate e Trihalomethanes, o que mudou apenas foram os quartis e a contagem, mas ainda assim mudou pouco.
#
# Vamos observar as outras variáveis:

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

sns.histplot(data=df, x="Solids", ax=axes[0], hue="Potability",kde=True,element="step")
axes[0].set_title('Distribuição da variável Solids')

sns.histplot(data=df, x="Chloramines", ax=axes[1], hue="Potability",kde=True,element="step")
axes[1].set_title('Distribuição da variável Chloramines')

sns.histplot(data=df, x="Conductivity", ax=axes[2], hue="Potability",kde=True,element="step")
axes[2].set_title('Distribuição da variável Conductivity')
# Out:
# Text(0.5, 1.0, 'Distribuição da variável Conductivity')

# %% [markdown]
# As variáveis Solids, Conductivity e Chloramines também seguem distribuições normais. A ordem de grandeza entre elas varia bastante, mas isso será corrigido com a normalização.
#
# No que diz respeito a potabilidade da água, assim como as variáveis iniciais, o comportamento é bastante similar para essas variáveis também. O que esses gráficos nos mostram, além desse comportamento similar, é que há mais elementos no dataset não potáveis (0) do que potáveis (1). A ver pelo eixo y que traz a somatória (contagem) dos elementos por intervalo do valor da variável (eixo x).

# %%
print(f"Desvios padrões:\n {df[['Solids', 'Chloramines', 'Conductivity']].std()}")
print(f"\nMédias:\n: {df[['Solids', 'Chloramines', 'Conductivity']].mean()}")
# Out:
# Desvios padrões:
#  Solids          8768.570828
# Chloramines        1.583085
# Conductivity      80.824064
# dtype: float64
#
# Médias:
# : Solids          22014.092526
# Chloramines         7.122277
# Conductivity      426.205111
# dtype: float64

# %% [markdown]
# A curva normal nos traz que 68.26% dos dados se encontram a 1 desvio padrão positivo ou negativo da média. Em termos práticos, isso significa que:
#
# - Solids: a média é de ~22014 e 68.26% dos dados estão entre 13246 e 30782.
# - Chloramines: a média é de ~7 e 68.26% dos dados estão entre 5.5 e 8.5.
# - Conductivity: a média é de ~426 e 68.26% dos dados estão entre 346 e 506.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)

sns.histplot(data=df, x="Organic_carbon", ax=axes[0],  hue="Potability",kde=True,element="step")
axes[0].set_title('Distribuição da variável Organic_carbon')

sns.histplot(data=df, x="Turbidity", ax=axes[1],  hue="Potability",kde=True,element="step")
axes[1].set_title('Distribuição da variável Turbidity')
# Out:
# Text(0.5, 1.0, 'Distribuição da variável Turbidity')

# %% [markdown]
# Para as variáveis Organic_Carbon e Turbidity, o mesmo se repete. Há mais elementos não potáveis no dataset, mas o comportamento estatístico dos potáveis e não potáveis segue a mesma distribuição e tem média, moda e mediana parecida. A conferir:

# %%
print(f"Média de Organic_Carbon para água não potável: {round(df.query('Potability == 0')['Organic_carbon'].mean(), 2)}")
print(f"Média de Organic_Carbon para água potável: {round(df.query('Potability == 1')['Organic_carbon'].mean(), 2)}")
print('\n')
print(f"Mediana de Organic_Carbon para água não potável: {round(df.query('Potability == 0')['Organic_carbon'].median(), 2)}")
print(f"Mediana de Organic_Carbon para água potável: {round(df.query('Potability == 1')['Organic_carbon'].median(), 2)}")
# Out:
# Média de Organic_Carbon para água não potável: 14.36
# Média de Organic_Carbon para água potável: 14.16
#
#
# Mediana de Organic_Carbon para água não potável: 14.29
# Mediana de Organic_Carbon para água potável: 14.16

# %% [markdown]
# A média e a mediana são praticamente a mesma.
#
# Vamos avaliar agora gráficos de dispersão para ver se encontramos divergências entre potável x não potável.

# %%
sns.lmplot(x="ph", y="Solids", col="Potability", hue="Potability", data=df,
           col_wrap=2, ci=None, palette="muted", height=4)

# %% [markdown]
# Olha que interessante.
#
# Plotamos uma linah de tendência com regressão linear e podemos observar algumas coisas:
#
# 1. Os dados são distribuiídos de maneira meio aleatória e não seguem uma linearidade clara.
# 2. Entretanto, com a reta criada podemos ver claramente que a água não potável segue uma linearidade diferente da potável: quanto mais aumenta-se o pH, mais se diminui a solidez para água não potável.
# 3. Em compensação, na água potável, conforme se aumenta o pH, se aumenta também a soldiez.
# 4. Em conclusão, água com pH alto, se tiver solidez alta também tem mais chance de ser potável. Se tiver pH alto com solidez baixa, tem mais chance de ser não potável. E vice e versa.
#
# O próximo gráfico mostra isso interligado:

# %%
g = sns.lmplot(
    data=df,
    x="ph", y="Solids", hue="Potability",
    height=5
)

# %% [markdown]
# Vejamos as próximas variáveis:

# %%
g = sns.lmplot(
    data=df,
    x="Chloramines", y="Sulfate", hue="Potability",
    height=5
)

# %% [markdown]
# Ao compararmos as cloraminas e o sulfato, podemos observar que tanto potável quanto nao potável tem praticamente uma distribuição aleatória. Mas, forçando a barra, potável (1) segue uma curva linear crescente quanto não potável uma constante.
#
# A partir desse gráfico não podemos concluir muitas coisas: tanto potável quanto não potável podem assumir uma série de valores. A impressão que dá, na verdade, é que os valores para não potável estão mais concentrados apenas.
#
# Vamos observar mais detalhes sobre essas retas criadas:

# %%
from scipy import stats
import numpy as np

x = np.array(df.query('Potability == 0')['Chloramines'])
y = np.array(df.query('Potability== 0')['Sulfate'])

x_ = np.array(df.query('Potability == 1')['Chloramines'])
y_ = np.array(df.query('Potability== 1')['Sulfate'])

slope, intercept, r_value, p_value, std_err = stats.linregress(df.Chloramines, df.Sulfate)
slope_, intercept_, r_value_, p_value, std_err_ = stats.linregress(x_,y_)

print(f"Fórmula da regressão para Chloramines x Sufalte para água potável: y={round(slope_,2)}x + {round(intercept_, 2)}")
print('\n')
print(f"Fórmula da regressão para Chloramines x Sulfate para água não potável: y={round(slope,2)}x + {round(intercept, 2)}")
# Out:
# Fórmula da regressão para Chloramines x Sufalte para água potável: y=1.56x + 321.66
#
#
# Fórmula da regressão para Chloramines x Sulfate para água não potável: y=0.54x + 329.91

# %% [markdown]
# Na verdade a água não potável não segue uma constante, mas sua inclinação é menor (0.54) e por isso dá a entender que é quase constante.
#
# Legal, vamos seguir.

# %%
g = sns.lmplot(
    data=df,
    x="Conductivity", y="Organic_carbon", hue="Potability",
    height=5
)

# %% [markdown]
# A condutividade x Carbono Orgânico também não apresenta nada muito conclusivo a primeira olhada, mas podemos ver que as duas retas, tanto para potável quanto para não potável, são lineares crescentes, ou seja, quando a condutividade auemnta, o carbono orgânico aumenta também (bem pouco, a inclinação deve ser baixa) tanto para casos de água potável como não potável.
#
# Por fim:

# %%
g = sns.lmplot(
    data=df,
    x="Trihalomethanes", y="Turbidity", hue="Potability",
    height=5
)

# %%
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %% [markdown]
# Como vem se repetindo, o comportamento das variáveis Trihalomethanes e Turbidity é também inclonclusivo, mas as retas seguem uma linearidade negativa, ou seja, quando a variável Trihalomethanes aumenta, a Turbidity diminui, mesmo que bem pouco, tanto para potávl quanto não.
#
# Vamos implementar o Kmeans e ver se a clusterização vai separar de maneira parecida os casos potáveis e não potáveis:

# %%
from sklearn.cluster import KMeans 
kmeans = KMeans(n_clusters = 2) 
pred_y = kmeans.fit_predict(df.drop('Potability', axis=1))
df['predicao'] = pred_y

# %%
pred_y
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int32)

# %%
df.head(2)
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability  predicao
# 0       10.379783        86.990970   2.963135           0         0
# 1       15.180013        56.329076   4.500656           0         0

# %%
df.predicao.value_counts()
# Out:
# 0    2034
# 1    1242
# Name: predicao, dtype: int64

# %%
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[7.13930787e+00, 1.96952293e+02, 1.65124626e+04, 7.18157901e+00,
#         3.36816790e+02, 4.24221854e+02, 1.42423332e+01, 6.65909100e+01,
#         3.96020404e+00],
#        [6.98471933e+00, 1.95412582e+02, 3.10474139e+04, 7.02490637e+00,
#         3.28782629e+02, 4.29461490e+02, 1.43549775e+01, 6.60767443e+01,
#         3.97759360e+00]])

# %% [markdown]
# Essas são as coordenadas dos centroides de cada cluster: do potável e não potável.

# %%
centroids.shape
# Out:
# (2, 9)

# %% [markdown]
# O resultado são 2 clusters em 9 dimensões. Observe que os próprios centros do cluster são pontos de 9 dimensões e podem ser interpretados como a potabilidade "típica" dentro do cluster.

# %% [markdown]
# Acima temos as coordenadas dos centroides de cada opção, ou seja, o centróide no eixo 9D de potável e não-potável.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)

sns.scatterplot(data=df, ax=axes[0], x='ph', y=df.Hardness.index, hue="Potability")
axes[0].set_title('Distribuição do pH pela potabilidade real')

sns.scatterplot(data=df, ax=axes[1], x='ph', y=df.Hardness.index, hue="predicao")
axes[1].set_title('Distribuição do pH pela potabilidade do modelo de predição')
# Out:
# Text(0.5, 1.0, 'Distribuição do pH pela potabilidade do modelo de predição')

# %% [markdown]
# Podemos observar que no gráfico da esquerda há intervalos muito claros que de dureza da água x pH que definem se a água é potável ou não e em nosso modelo os dados parecem aleatoriamente distribuídos e não é possível enxergar um padrão.
#
# Vamos ver outras variáveis:

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)

sns.scatterplot(data=df, ax=axes[0], x='Chloramines', y=df.Solids.index, hue="Potability")
axes[0].set_title('Distribuição da Cloramina pela potabilidade real')

sns.scatterplot(data=df, ax=axes[1], x='Chloramines', y=df.Solids.index, hue="predicao")
axes[1].set_title('Distribuição da CLoramina pela potabilidade do modelo de predição')
# Out:
# Text(0.5, 1.0, 'Distribuição da CLoramina pela potabilidade do modelo de predição')

# %% [markdown]
# O mesmo se repete para as variáveis de solidez e cloraminas: enquanto que os intervalos para esses variáveis são claramente nítidos para comparação de água potável e não na vida real, nosso modelo não refletiu bem esse comportamento.
#
# Tudo bem que para os gráficos da esquerda, o eixo y representa o índice apenas, então também não é algo muito conclusivo.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)

sns.scatterplot(data=df, ax=axes[0], x='Sulfate', y=df.Conductivity.index, hue="Potability")
axes[0].set_title('Distribuição do Sulfato pela potabilidade real')

sns.scatterplot(data=df, ax=axes[1], x='Sulfate', y=df.Conductivity.index, hue="predicao")
axes[1].set_title('Distribuição do Sulfato pela potabilidade do modelo de predição')
# Out:
# Text(0.5, 1.0, 'Distribuição do Sulfato pela potabilidade do modelo de predição')

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)

sns.scatterplot(data=df, ax=axes[0], x='Organic_carbon', y=df.Trihalomethanes.index, hue="Potability")
axes[0].set_title('Distribuição do Carbono Orgânico pela potabilidade real')

sns.scatterplot(data=df, ax=axes[1], x='Organic_carbon', y=df.Trihalomethanes.index, hue="predicao")
axes[1].set_title('Distribuição do Carbono Orgânico pela potabilidade do modelo de predição')
# Out:
# Text(0.5, 1.0, 'Distribuição do Carbono Orgânico pela potabilidade do modelo de predição')

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)

sns.scatterplot(data=df, ax=axes[0], x='Turbidity', y=df.Turbidity.index, hue="Potability")
axes[0].set_title('Distribuição da Turbidez pela potabilidade real')

sns.scatterplot(data=df, ax=axes[1], x='Turbidity', y=df.Turbidity.index, hue="predicao")
axes[1].set_title('Distribuição da Turbidez pela potabilidade do modelo de predição')
# Out:
# Text(0.5, 1.0, 'Distribuição da Turbidez pela potabilidade do modelo de predição')

# %% [markdown]
# O mesmo comportamento se repetiu para todas as variáveis: o algoritmo Kmeans não conseguiu segmentar de maneira muito assertiva os dados:

# %%
sns.relplot(x="ph", y=df.ph.index, hue="Potability", size="predicao",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=df)

# %% [markdown]
# Por incrível que pareça, esse é um dos melhores gráficos para avaliarmos o que o modelo acertou e errou:
#
# A cor das bolhas simboliza a potabilidade da água: azul é não potável e laranja potável.
#
# Já o tamanho das bolinhas simboliza nossa predição para a potabilidade: bolinhas grandes são um cluster e vamos assumir que nosso modelo acertou a maioria e portanto bolhas grandes são não potáveis e as pequenas potáveis.
#
# Dessa forma, todas bolhas azuis devem assumir o mesmo tamanho (grande) e as bolhas laranjas assumir o tamanho pequeno. Bolhas azuis pequenas e bolhas laranjas grandes são predições erradas.
#
# Dá pra ver que ele acertou boa parte dos não potáveis, mas classificou como não potável várias amostras que eram na verdade potáveis.
#
# Interessante.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)

sns.scatterplot(data=df, ax=axes[0], x='Potability', y=df.Potability.index)
axes[0].set_title('Distribuição da potabilidade real')

sns.scatterplot(data=df, ax=axes[1], x='predicao', y=df.predicao.index)
axes[1].set_title('Distribuição da potabilidade do modelo de predição')
# Out:
# Text(0.5, 1.0, 'Distribuição da potabilidade do modelo de predição')

# %% [markdown]
# A diferença é visual.
#
# Vamos ver numericamente quantos de fato o modelo acertou:

# %%
print(df.Potability.value_counts())
print(df.predicao.value_counts())
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64
# 0    2034
# 1    1242
# Name: predicao, dtype: int64

# %% [markdown]
# Na amostra dos dados existem 1998 não potáveis e 1278 potáveis.
#
# O modelo identificou 2034 não potáveis e 1242 potáveis.

# %%
df['resultado'] = df['Potability'] == df['predicao']

# %% [markdown]
# A nova coluna resultado traz se a predição foi correta ou não.

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.775777    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability  predicao  resultado
# 0       10.379783        86.990970   2.963135           0         0       True
# 1       15.180013        56.329076   4.500656           0         0       True
# 2       16.868637        66.420093   3.055934           0         0       True
# 3       18.436524       100.341674   4.628771           0         0       True
# 4       11.558279        31.997993   4.075075           0         0       True

# %%
df['resultado'].value_counts()
# Out:
# True     1758
# False    1518
# Name: resultado, dtype: int64

# %% [markdown]
# Observando podemos ver que o modelo classificou corretamente (potável e potável e não potável e não potável) 1758 e errou 1518 vezes, um acerto de ~54%.
